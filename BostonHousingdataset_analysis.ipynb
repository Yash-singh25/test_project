# %% [markdown]
# <a href="https://colab.research.google.com/github/Yash-singh25/test_project/blob/master/BostonHousingdataset_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow==2.0.0
# Out:
# ...
#      |████████████████████████████████| 86.3MB 47kB/s
# ...
#      |████████████████████████████████| 3.8MB 47.6MB/s
# ...
#      |████████████████████████████████| 450kB 44.3MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=4cf5af1a4e37ba25216a96fe99f159ac4b64fdb3520ad51738cdf2cfc0949cd6
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow-probability 0.10.0 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# ...
#   Found existing installation: tensorboard 2.2.2
#     Uninstalling tensorboard-2.2.2:
#       Successfully uninstalled tensorboard-2.2.2
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: tensorflow-estimator 2.2.0
#     Uninstalling tensorflow-estimator-2.2.0:
#       Successfully uninstalled tensorflow-estimator-2.2.0
# ...

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import *
from sklearn.model_selection import *
from sklearn.linear_model import *
from sklearn.preprocessing import*
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
dataset1 = tf.keras.utils.get_file('BostonHousing' , 'https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv')
# Out:
# ...
# 40960/35735 [==================================] - 0s 0us/step

# %%
csv_columns = ["crim","zn","indus","chas","nox","rm","age","dis","rad","tax","ptratio","b","lstat","medv"]

# %%
dataset2 = pd.read_csv(dataset1 , names = csv_columns , header = 0)

# %%
dataset2.head()
# Out:
#       crim    zn  indus  chas    nox  ...  tax  ptratio       b  lstat  medv
# 0  0.00632  18.0   2.31     0  0.538  ...  296     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07     0  0.469  ...  242     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07     0  0.469  ...  242     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18     0  0.458  ...  222     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18     0  0.458  ...  222     18.7  396.90   5.33  36.2
#
# [5 rows x 14 columns]

# %%
print(dataset2.shape)
# Out:
# (506, 14)

# %%
dataset2.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
for i in (dataset2.keys()):
  print('the number of unique values for {} is {}'.format(i , len(dataset2[i].unique())))
# Out:
# the number of unique values for crim is 504
# the number of unique values for zn is 26
# the number of unique values for indus is 76
# the number of unique values for chas is 2
# the number of unique values for nox is 81
# the number of unique values for rm is 446
# the number of unique values for age is 356
# the number of unique values for dis is 412
# the number of unique values for rad is 9
# the number of unique values for tax is 66
# the number of unique values for ptratio is 46
# the number of unique values for b is 357
# the number of unique values for lstat is 455
# the number of unique values for medv is 229

# %%
X = np.array(dataset2.iloc[:,2]).reshape(-1,1)

# %%
X

# %%
y = np.array(dataset2.iloc[:,13]).reshape(-1,1)

# %%
plt.scatter(X,y)

# %%
x_train , x_test , y_train , y_test = train_test_split(X , y , test_size = 0.2 , random_state = 10)

# %%
obj = LinearRegression()
model = obj.fit(x_train , y_train)
predicted_test = obj.predict(x_test)
predicted_train = obj.predict(x_train)

# %%
mean_squared_error(y_train,predicted_train)
# Out:
# 57.12012301672838

# %%
mean_absolute_error(y_train ,predicted_train)
# Out:
# 5.473458223819071

# %%
obj.coef_
# Out:
# array([-0.64048558])

# %%
obj.intercept_
# Out:
# 29.2369035239441

# %%
x_train.shape
# Out:
# (404, 1)

# %%
 k = (obj.coef_)*x_train + np.ones([404,1])*obj.intercept_

# %%
k.shape
# Out:
# (404, 1)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train,predicted_train , color = 'r')

# %%
J = np.sum((y_train - predicted_train)**2)/(2*m)

# %%
for i in range(13):
  X = np.array(dataset2.iloc[:,i]).reshape(-1,1)
  y = np.array(dataset2.iloc[:,13]).reshape(-1,1)
  x_train , x_test , y_train , y_test = train_test_split(X , y , test_size = 0.2 , random_state = 10)
  obj = LinearRegression()
  model = obj.fit(x_train , y_train)
  predicted_test = obj.predict(x_test)
  predicted_train = obj.predict(x_train)
  print('the mean square error for {} is {}'.format(csv_columns[i],mean_squared_error(y_train,predicted_train)))
  print('the mean absolute error for {} is {}'.format(csv_columns[i],mean_absolute_error(y_train ,predicted_train)))
  plt.scatter(x_train,y_train)
  plt.plot(x_train,predicted_train , color = 'r')
  plt.xlabel('x-plot for {}'.format(csv_columns[i]))
  J = np.sum((y_train - predicted_train)**2)/(2*m)
  print('the cost of {} is {}'.format(csv_columns[i],J))
  plt.show()
# Out:
# the mean square error for crim is 65.09914213865933
# the mean absolute error for crim is 5.7805242792767
# the cost of crim is 32.549571069329666
# the mean square error for zn is 64.21694605968271
# the mean absolute error for zn is 5.669767365927605
# the cost of zn is 32.108473029841356
# the mean square error for indus is 57.12012301672838
# the mean absolute error for indus is 5.473458223819071
# the cost of indus is 28.56006150836419
# the mean square error for chas is 75.11774762931643
# the mean absolute error for chas is 6.302709422135848
# the cost of chas is 37.55887381465821
# the mean square error for nox is 61.10088059908386
# the mean absolute error for nox is 5.630981109665481
# the cost of nox is 30.55044029954193
# the mean square error for rm is 43.33855418562697
# the mean absolute error for rm is 4.389215705190225
# the cost of rm is 21.669277092813484
# the mean square error for age is 63.95865733084936
# the mean absolute error for age is 5.569522252115958
# ...
